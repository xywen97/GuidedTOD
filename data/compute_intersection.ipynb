# %%
import json

guideline_path = "raw/guidelines.json"

with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))

for scenario in scenarios:
    flows = guidelines[scenario]['subflows']
    # calculate the average length of the subflows
    subflows_names = list(flows.keys())
    total_length = 0
    for subflows_name in subflows_names:
        subflows = flows[subflows_name]
        actions = subflows['actions']
        total_length += len(actions)
        print("Subflow: ", subflows_name, "Length: ", len(actions))
    avg_length = total_length / len(subflows_names)

    print("Scenario: ", scenario, "Average Length: ", avg_length)
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# Subflow:  Initiate Refund Length:  5
# Subflow:  Update Refund Length:  4
# Subflow:  Refund Status Length:  4
# Subflow:  Return Due to Stain Length:  6
# Subflow:  Return Due to Color Length:  6
# Subflow:  Return Due to Size Length:  6
# Scenario:  Product Defect Average Length:  5.166666666666667
# Subflow:  Status Mystery Fee Length:  5
# Subflow:  Status Delivery Time Length:  5
# Subflow:  Status Payment Method Length:  4
# Subflow:  Status Quantity Length:  5
# Subflow:  Manage Upgrade Length:  5
# Subflow:  Manage Downgrade Length:  5
# Subflow:  Manage Create Length:  5
# Subflow:  Manage Cancel Length:  5
# Scenario:  Order Issue Average Length:  4.875
# Subflow:  Recover Username Length:  3
# Subflow:  Recover Password Length:  4
# Subflow:  Reset Two-Factor Auth Length:  3
# Scenario:  Account Access Average Length:  3.3333333333333335
# Subflow:  Invalid Credit Card Length:  4
# Subflow:  Cart Not Updating Length:  4
# Subflow:  Search Not Working Length:  5
# Subflow:  Website Too Slow Length:  5
# Scenario:  Troubleshoot Site Average Length:  4.5
# Subflow:  Status Service Added Length:  6
# Subflow:  Status Service Removed Length:  6
# Subflow:  Status Shipping Question Length:  3
# Subflow:  Status Credit Missing Length:  5
# Subflow:  Manage Change Address Length:  4
# Subflow:  Manage Change Name Length:  4
# Subflow:  Manage Change Phone Length:  4
# Subflow:  Manage Payment Method Length:  4
# Scenario:  Manage Account Average Length:  4.5
# Subflow:  Bad Price Competitor Length:  5
# Subflow:  Bad Price Yesterday Length:  5
# Subflow:  Out-of-Stock General Length:  4
# Subflow:  Out-of-Stock One Item Length:  4
# Subflow:  Promo Code Invalid Length:  5
# Subflow:  Promo Code Out of Date Length:  5
# Subflow:  Mistimed Billing Already Returned Length:  5
# Subflow:  Mistimed Billing Never Bought Length:  5
# Scenario:  Purchase Dispute Average Length:  4.75
# Subflow:  Shipping Status Length:  6
# Subflow:  Manage Shipping Length:  4
# Subflow:  Missing Item Length:  6
# Subflow:  Shipping Cost Length:  5
# Scenario:  Shipping Issue Average Length:  5.25
# Subflow:  Status Active Length:  5
# Subflow:  Status Due Amount Length:  5
# Subflow:  Status Due Date Length:  5
# Subflow:  Manage Pay Bill Length:  5
# Subflow:  Manage Extension Length:  5
# Subflow:  Manage Dispute Bill Length:  5
# Scenario:  Subscription Inquiry Average Length:  5.0
# Subflow:  Boots FAQ Length:  4
# Subflow:  Shirt FAQ Length:  4
# Subflow:  Jeans FAQ Length:  4
# Subflow:  Jacket FAQ Length:  4
# Scenario:  Single-Item Query Average Length:  4.0
# Subflow:  Pricing FAQ Length:  4
# Subflow:  Membership FAQ Length:  4
# Subflow:  Timing FAQ Length:  4
# Subflow:  Policy FAQ Length:  4
# Scenario:  Storewide Query Average Length:  4.0

# %% [markdown]
# ### Average Action Length in the Training Set

# %%
import json
import os

guideline_path = "raw/guidelines.json"

with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))


# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

data_actions = list(read_json_lines('processed/train_AST_abcd_woaction_flow_all.json'))

action_length = {}

for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    action_length[scenario_name] = {}

for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_length[action_scenario]:
        action_length[action_scenario][convo_id] = 1
    else:
        action_length[action_scenario][convo_id] += 1

print("Action Length: ", action_length)

# calculate the average length for each scenario
for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    convo_ids = action_length[scenario_name].keys()
    total_length = 0
    for convo_id in convo_ids:
        total_length += action_length[scenario_name][convo_id]
    avg_length = total_length / len(convo_ids)
    print("Scenario: ", scenario, "Average Length: ", avg_length)
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# Action Length:  {'product_defect': {1746: 4, 3070: 3, 6723: 2, 8097: 4, 7249: 4, 8240: 4, 2869: 5, 5565: 2, 5157: 2, 9505: 4, 6677: 5, 632: 2, 7639: 4, 8909: 4, 3949: 5, 7308: 7, 7123: 5, 6665: 5, 9671: 5, 5437: 5, 5670: 5, 1847: 5, 8800: 5, 2740: 5, 9724: 4, 4534: 2, 9372: 5, 9393: 4, 6909: 2, 2989: 2, 9081: 5, 905: 2, 6174: 4, 4803: 2, 8065: 8, 7473: 4, 6099: 4, 2568: 3, 4825: 2, 5977: 2, 7300: 6, 1966: 4, 4791: 2, 1061: 6, 1302: 4, 2005: 7, 5998: 4, 1874: 5, 4553: 5, 9657: 5, 5750: 4, 2976: 6, 318: 6, 8022: 5, 8305: 4, 391: 6, 199: 8, 8608: 5, 7916: 5, 6181: 5, 7921: 5, 10418: 5, 6313: 5, 3884: 4, 7122: 5, 706: 4, 9873: 4, 3396: 6, 7196: 5, 7174: 4, 4999: 5, 6413: 5, 6675: 4, 9868: 3, 2918: 5, 5854: 3, 7234: 5, 5480: 2, 3153: 6, 7829: 4, 5076: 2, 5331: 4, 7525: 3, 971: 5, 8071: 3, 4812: 2, 3166: 5, 3338: 4, 5187: 5, 8795: 5, 1134: 4,
: 4, 3937: 4, 10498: 5, 6493: 3, 9546: 4, 10126: 5, 7678: 5, 1989: 5, 8616: 4, 2937: 4, 4071: 2, 6934: 5, 6086: 5, 6597: 4, 1781: 5, 5841: 5, 1501: 5, 441: 2, 5955: 2, 10148: 4, 5230: 2, 7401: 4, 6704: 4, 5553: 5, 3996: 6, 6622: 2, 6894: 5, 7909: 2, 4223: 5, 8037: 5, 7724: 4, 9094: 5, 2310: 5, 631: 4, 8793: 4, 8593: 5, 9064: 5, 10029: 5, 7641: 5, 9130: 5, 8557: 5, 1538: 5, 9855: 4, 4138: 5, 4055: 5, 6323: 5, 4725: 2, 10508: 5, 7239: 4, 10152: 4, 9419: 5, 10232: 5, 5825: 2, 7657: 2, 3654: 3, 1207: 3, 2451: 5, 10321: 2, 2106: 7, 6072: 4, 3770: 4, 4262: 4, 10075: 5, 2485: 4, 9815: 5, 6960: 5, 5061: 7, 4083: 2, 2830: 2, 9516: 4, 8649: 2, 1038: 6, 7775: 5, 3950: 4, 2946: 4, 8002: 2, 7587: 5, 5099: 2, 8917: 3, 6848: 5, 5561: 5, 709: 2, 3929: 2, 6097: 5, 10176: 5, 8971: 5, 4525: 5, 9223: 3, 6195: 2, 6615: 5, 7998: 4, 3346: 2, 10033: 5, 5167: 4, 6807: 5, 5778: 2, 898: 2, 6962: 6, 9185: 5, 5607: 3, 8767: 10, 2024: 4, 8694: 4, 2789: 4, 7391: 4, 5250: 3, 1480: 6, 8806: 2, 323: 3, 2528: 4, 834: 3, 8739: 5, 7649: 4, 8206: 2, 9179: 5, 5419: 3, 2266: 5, 6359: 5, 1836: 5, 5268: 5, 2358: 3, 9218: 2, 1340: 5, 656:  ...
# Scenario:  Product Defect Average Length:  4.179606025492468
# Scenario:  Order Issue Average Length:  3.997593261131167
# Scenario:  Account Access Average Length:  2.807556080283353
# Scenario:  Troubleshoot Site Average Length:  2.706959706959707
# Scenario:  Manage Account Average Length:  3.9353146853146854
# Scenario:  Purchase Dispute Average Length:  3.625874125874126
# Scenario:  Shipping Issue Average Length:  4.433660933660934
# Scenario:  Subscription Inquiry Average Length:  4.540389972144847
# Scenario:  Single-Item Query Average Length:  3.072619047619048
# Scenario:  Storewide Query Average Length:  3.272935779816514

# %% [markdown]
# ### Average Action Length in the Testing Set

# %%
import json
import os

guideline_path = "raw/guidelines.json"

with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))


# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

data_actions = list(read_json_lines('processed/test_AST_abcd_woaction_flow_all.json'))

action_length = {}

for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    action_length[scenario_name] = {}

for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_length[action_scenario]:
        action_length[action_scenario][convo_id] = 1
    else:
        action_length[action_scenario][convo_id] += 1

print("Action Length: ", action_length)

# calculate the average length for each scenario
, 3516: 3, 9363: 3, 955: 2, 8833: 1, 2258: 3, 8984: 3, 7805: 2}, 'manage_account': {5718: 3, 1941: 4, 4685: 2, 7134: 3, 1473: 3, 7530: 2, 1246: 4, 4730: 8, 10586: 4, 2874: 4, 9641: 4, 10165: 3, 3261: 4, 10318: 3, 7660: 5, 6290: 5, 3000: 4, 1045: 4, 8680: 6, 42 ...
# Scenario:  Product Defect Average Length:  4.257142857142857
# Scenario:  Order Issue Average Length:  3.676190476190476
# Scenario:  Account Access Average Length:  2.8686868686868685
# Scenario:  Troubleshoot Site Average Length:  2.70873786407767
# Scenario:  Manage Account Average Length:  3.838235294117647
# Scenario:  Purchase Dispute Average Length:  3.5315315315315314
# Scenario:  Shipping Issue Average Length:  4.30188679245283
# Scenario:  Subscription Inquiry Average Length:  4.5212765957446805
# Scenario:  Single-Item Query Average Length:  3.150943396226415
# Scenario:  Storewide Query Average Length:  3.2149532710280373

# %% [markdown]
# ### Average Rounds in Train Set

# %%
import json
import os

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

def read_json(file):
    with open(file, 'r') as f:
        return json.load(f)
    
def write_json(file, obj):
    with open(file, 'w') as f:
        json.dump(obj, f, indent=2)

def select_longest_dialogue_raw(data):
    # select the longest dialogue using the frequency of the convo_id appearing in the data
    guideline_path = "raw/guidelines.json"
    with open(guideline_path, "r") as f:
        guidelines = json.load(f)

    scenarios = guidelines.keys()
    print("Scenarios: ", list(scenarios))
    convo_id_freq = {}
    for scenario in scenarios:
        scenario_name = scenario.lower()
        scenario_name = scenario_name.replace("-", "_")
        scenario_name = scenario_name.replace(" ", "_")
        convo_id_freq[scenario_name] = {}
    for d in data:
        convo_id = d['convo_id']
        scenario = d['scenario']['flow']
        for turn in d['original']:
            if convo_id not in convo_id_freq[scenario]:
                convo_id_freq[scenario][convo_id] = 1
            else:
                convo_id_freq[scenario][convo_id] += 1
    
    return convo_id_freq

def main():
    data_raw = read_json('raw/abcd_v1.1.json')
    test_data_raw = data_raw['train']

    # longest_dialogue = select_longest_dialogue(test_data_raw, data_actions)
    dialogue_length = select_longest_dialogue_raw(test_data_raw)
    print(dialogue_length)

    # calculate the average length for each scenario
    for scenario in dialogue_length.keys():
        convo_ids = dialogue_length[scenario].keys()
        total_length = 0
        for convo_id in convo_ids:
            total_length += dialogue_length[scenario][convo_id]
        avg_length = total_length / len(convo_ids)
        print("Scenario: ", scenario, "Average Length: ", avg_length)

if __name__ == '__main__':
    main()
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
775: 27, 8955: 30, 8592: 25, 4631: 39, 10349: 26, 5899: 17, 9224: 31, 9590: 25, 4596: 26, 7639: 31, 420: 34, 9246: 43, 5013: 20, 6518: 32, 9937: 20, 9873: 25, 7760: 32, 4196: 31, 1060: 24, 4048: 30, 4138: 37, 2451: 28, 8854: 23, 8608: 29, 9372: 20, 9125: 22, 4223: 25, 8305: 28, 10422: 25, 3143: 13, 7637: 25, 9830: 33, 6641: 29, 7525: 33, 10404: 27, 7739: 25, 6665: 29, 622: 15, 4586: 20, 205: 23, 7078: 23, 1215: 37, 10126: 28, 9857: 31, 985: 36, 6807: 30, 4083: 26, 1966: 32, 6217: 21, 5629: 19, 8801: 19, 945: 19, 6022: 27, 6832: 18, 2789: 24, 318: 23, 6827: 27, 3288: 27, 10423: 22, 998: 32, 6597: 25, 9435: 27, 6998: 27, 2132: 24, 5230: 18, 2740: 27, 3556: 31, 1098: 19, 1038: 35, 868: 24, 4055: 34, 8627: 40, 5378: 25, 8728: 39, 7631: 11, 4803: 33, 5157: 17, 3285: 33, 505: 23, 6260: 34, 10176: 28, 9232: 24, 8875: 28, 2324: 21, 1989: 54, 3166: 28, 9064: 30, 1985: 21, 4041: 16, 6974: 25, 10078: 33, 8533: 31, 5561: 24, 8002: 16, 1279: 27, 6012: 34, 10210: 30, 3199: 27, 1300: 13, 9866: 15, 7647: 56, 8790: 23, 6174: 23, 9831: 37, 5144: 19, 2260: 44, 6331: 30, 441: 9, 232: 29, 9283: 34, 9546: 34, 8071: 25, 5266: 34, 4825: 12, 2817: 29, 1732: 27, 7559: 29, 7437: 27, 1642: 27, 4774: 37, 824: 30, 3486: 23, 8775: 28, 5284: 21, 6317: 29, 1491: 27, 7596: 27, 6061: 23, 10384: 24, 6313: 26, 5331: 34, 9223: 19, 5392: 41, 6963: 22, 10258: 24, 1562: 16, 3698: 26, 2120: 17, 1719: 42, 6425: 21, 8884: 21, 9218: 17, 707: 19, 1044: 22, 3153: 25, 5061: 34, 10321: 14, 3493: 3 ...
# Scenario:  product_defect Average Length:  26.61529548088065
# Scenario:  order_issue Average Length:  24.41756919374248
# Scenario:  account_access Average Length:  20.430932703659977
# Scenario:  troubleshoot_site Average Length:  20.347985347985347
# Scenario:  manage_account Average Length:  22.21153846153846
# Scenario:  purchase_dispute Average Length:  22.543123543123542
# Scenario:  shipping_issue Average Length:  26.237100737100736
# Scenario:  subscription_inquiry Average Length:  24.545961002785514
# Scenario:  single_item_query Average Length:  16.310714285714287
# Scenario:  storewide_query Average Length:  16.599770642201836

# %% [markdown]
# ### Average Rounds in Test Set

# %%
import json
import os

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

def read_json(file):
    with open(file, 'r') as f:
        return json.load(f)
    
def write_json(file, obj):
    with open(file, 'w') as f:
        json.dump(obj, f, indent=2)

def select_longest_dialogue_raw(data):
    # select the longest dialogue using the frequency of the convo_id appearing in the data
    guideline_path = "raw/guidelines.json"
    with open(guideline_path, "r") as f:
        guidelines = json.load(f)

    scenarios = guidelines.keys()
    print("Scenarios: ", list(scenarios))
    convo_id_freq = {}
    for scenario in scenarios:
        scenario_name = scenario.lower()
        scenario_name = scenario_name.replace("-", "_")
        scenario_name = scenario_name.replace(" ", "_")
        convo_id_freq[scenario_name] = {}
    for d in data:
        convo_id = d['convo_id']
        scenario = d['scenario']['flow']
        for turn in d['original']:
            if convo_id not in convo_id_freq[scenario]:
                convo_id_freq[scenario][convo_id] = 1
            else:
                convo_id_freq[scenario][convo_id] += 1
    
    return convo_id_freq

def main():
    data_raw = read_json('raw/abcd_v1.1.json')
    test_data_raw = data_raw['test']

    # longest_dialogue = select_longest_dialogue(test_data_raw, data_actions)
    dialogue_length = select_longest_dialogue_raw(test_data_raw)
    print(dialogue_length)

    # calculate the average length for each scenario
    for scenario in dialogue_length.keys():
        convo_ids = dialogue_length[scenario].keys()
        total_length = 0
        for convo_id in convo_ids:
            total_length += dialogue_length[scenario][convo_id]
        avg_length = total_length / len(convo_ids)
        print("Scenario: ", scenario, "Average Length: ", avg_length)

if __name__ == '__main__':
    main()
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# {'product_defect': {8141: 25, 4162: 26, 3342: 25, 1529: 29, 6805: 18, 10127: 39, 9366: 23, 9268: 22, 573: 21, 2269: 25, 2334: 41, 8102: 21, 9121: 26, 10124: 22, 7354: 29, 9421: 32, 6942: 27, 9415: 39, 7333: 22, 5357: 24, 8740: 27, 5046: 26, 6274: 20, 9737: 24, 8580: 30, 2984: 31, 1859: 23, 6957: 28, 3662: 32, 3764: 46, 9178: 30, 6587: 35, 4332: 29, 3567: 40, 6688: 26, 9967: 29, 10012: 20, 9880: 26, 9994: 37, 1972: 26, 6406: 27, 1179: 32, 9452: 14, 7859: 19, 7129: 19, 10347: 22, 7817: 16, 9310: 16, 2599: 27, 5374: 28, 3182: 40, 3538: 24, 6435: 29, 7722: 22, 9220: 20, 7782: 30, 8092: 28, 8855: 24, 533: 33, 3013: 27, 6069: 21, 2669: 33, 2509: 21, 3450: 32, 10259: 28, 1229: 43, 1526: 26, 10222: 19, 6255: 32, 8197: 26, 3332: 30, 3054: 26, 2673: 19, 9225: 28, 3294: 31, 9340: 31, 4961: 29, 5531: 26, 1064: 35, 4072: 30, 5436: 24, 1037: 25, 389: 19, 3839: 27, 9454: 13, 10298: 34, 968: 27, 3499: 30, 8810: 24, 8330: 28, 4200: 27, 4227: 24, 8354: 18, 7947: 23, 8271: 19, 5787: 29, 7331: 29, 9577: 33, 4982: 27, 7423: 28, 6259: 23, 10228: 19, 5410: 26, 2090: 45, 838: 40}, 'order_issue': {10061: 18, 7961: 24, 7950: 18, 2914: 39, 10392: 32, 541: 21, 9986: 27, 6080: 22, 4177: 20, 6386: 30, 799: 16, 2565: 32, 4986: 15, 3792: 16, 2498: 26, 10391: 22, 5563: 28, 3536: 37, 8314: 26, 9163: 20, 3707: 56, 3694: 25, 8814: 21, 1054: 15, 7688: 26, 4284: 17, 4197: 24, 5689: 
12, 2088: 23, 5428: 14, 2623: 13, 7628: 22, 5376: 33, 215: 14, 1656: 19, 6339: 13, 9760: 21, 5914: 15, 4911: 27, 3858: 48, 363: 19, 2094: 21, 1021: 22, 3790: 17, 6011: 10, 3768: 37, 6348: 24, 5530: 26, 4005: 15, 2607: 20, 4454: 18, 468: 24, 4889: 19, 2715: 20, 6951: 15, 2676: 22, 9025: 20, 10082: 20, 9029: 17, 2748: 16, 1087: 10, 10274: 17, 1922: 18, 699 ...
# Scenario:  product_defect Average Length:  27.095238095238095
# Scenario:  order_issue Average Length:  24.590476190476192
# Scenario:  account_access Average Length:  20.646464646464647
# Scenario:  troubleshoot_site Average Length:  20.9126213592233
# Scenario:  manage_account Average Length:  23.83823529411765
# Scenario:  purchase_dispute Average Length:  22.72972972972973
# Scenario:  shipping_issue Average Length:  24.42452830188679
# Scenario:  subscription_inquiry Average Length:  24.48936170212766
# Scenario:  single_item_query Average Length:  16.21698113207547
# Scenario:  storewide_query Average Length:  16.72897196261682

# %% [markdown]
# ### Compute the Intersections between Guidelines and Train Set

# %%
import json

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

guideline_path = "raw/guidelines.json"
with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))
guideline_action_seq = {}
for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    guideline_action_seq[scenario_name] = {}

    subflows = guidelines[scenario]['subflows']
    subflows_names = list(subflows.keys())
    for subflows_name in subflows_names:
        subflow = subflows[subflows_name]
        actions = subflow['actions']

        action_only = []
        for action in actions:
            action_only.append(action['button'])
        
        guideline_action_seq[scenario_name][subflows_name] = action_only

# print(json.dumps(guideline_action_seq, indent=2))
guideline_action_seq_scenario = {}
for scenario in guideline_action_seq.keys():
    for subflow in guideline_action_seq[scenario].keys():
        if scenario not in guideline_action_seq_scenario:
            guideline_action_seq_scenario[scenario] = []
        tmp = guideline_action_seq[scenario][subflow]
        for i in range(len(tmp)):
            tmp[i] = tmp[i].strip()
            tmp[i] = tmp[i].lower()
            tmp[i] = tmp[i].replace(" ", "-")
        guideline_action_seq_scenario[scenario].append(tmp)

# print(json.dumps(guideline_action_seq_scenario, indent=2))

data_actions = list(read_json_lines('processed/train_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in action_seq_scenario:
            action_seq_scenario[scenario] = []

        action_seq_scenario[scenario].append(action_seq[convo_id][scenario])

# print(json.dumps(action_seq_scenario, indent=2))

# compute how many action sequences are in the guideline
for scenario in action_seq_scenario.keys():
    guideline_actions = guideline_action_seq_scenario[scenario]
    action_sequences = action_seq_scenario[scenario]
    total = 0
    for action_sequence in action_sequences:
        if action_sequence in guideline_actions:
            total += 1
    print("Scenario: ", scenario, "Total: ", total, "Percentage: ", total / len(action_sequences), "Length: ", len(action_sequences))
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# Scenario:  product_defect Total:  142 Percentage:  0.1645422943221321 Length:  863
# Scenario:  shipping_issue Total:  82 Percentage:  0.10073710073710074 Length:  814
# Scenario:  single_item_query Total:  0 Percentage:  0.0 Length:  840
# Scenario:  manage_account Total:  123 Percentage:  0.21503496503496503 Length:  572
# Scenario:  subscription_inquiry Total:  0 Percentage:  0.0 Length:  718
# Scenario:  troubleshoot_site Total:  0 Percentage:  0.0 Length:  819
# Scenario:  storewide_query Total:  0 Percentage:  0.0 Length:  872
# Scenario:  purchase_dispute Total:  0 Percentage:  0.0 Length:  858
# Scenario:  account_access Total:  225 Percentage:  0.26564344746162927 Length:  847
# Scenario:  order_issue Total:  68 Percentage:  0.08182912154031288 Length:  831

# %% [markdown]
# ### Compute the Intersections between Guidelines and Test Set

# %%
import json

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

guideline_path = "raw/guidelines.json"
with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))
guideline_action_seq = {}
for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    guideline_action_seq[scenario_name] = {}

    subflows = guidelines[scenario]['subflows']
    subflows_names = list(subflows.keys())
    for subflows_name in subflows_names:
        subflow = subflows[subflows_name]
        actions = subflow['actions']

        action_only = []
        for action in actions:
            action_only.append(action['button'])
        
        guideline_action_seq[scenario_name][subflows_name] = action_only

# print(json.dumps(guideline_action_seq, indent=2))
guideline_action_seq_scenario = {}
for scenario in guideline_action_seq.keys():
    for subflow in guideline_action_seq[scenario].keys():
        if scenario not in guideline_action_seq_scenario:
            guideline_action_seq_scenario[scenario] = []
        tmp = guideline_action_seq[scenario][subflow]
        for i in range(len(tmp)):
            tmp[i] = tmp[i].strip()
            tmp[i] = tmp[i].lower()
            tmp[i] = tmp[i].replace(" ", "-")
        guideline_action_seq_scenario[scenario].append(tmp)

# print(json.dumps(guideline_action_seq_scenario, indent=2))

data_actions = list(read_json_lines('processed/test_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in action_seq_scenario:
            action_seq_scenario[scenario] = []

        action_seq_scenario[scenario].append(action_seq[convo_id][scenario])

# print(json.dumps(action_seq_scenario, indent=2))

# compute how many action sequences are in the guideline
for scenario in action_seq_scenario.keys():
    guideline_actions = guideline_action_seq_scenario[scenario]
    action_sequences = action_seq_scenario[scenario]
    total = 0
    for action_sequence in action_sequences:
        if action_sequence in guideline_actions:
            total += 1
    print("Scenario: ", scenario, "Total: ", total, "Percentage: ", total / len(action_sequences), "Length: ", len(action_sequences))
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# Scenario:  storewide_query Total:  0 Percentage:  0.0 Length:  107
# Scenario:  subscription_inquiry Total:  0 Percentage:  0.0 Length:  94
# Scenario:  single_item_query Total:  0 Percentage:  0.0 Length:  106
# Scenario:  troubleshoot_site Total:  0 Percentage:  0.0 Length:  103
# Scenario:  purchase_dispute Total:  0 Percentage:  0.0 Length:  111
# Scenario:  account_access Total:  25 Percentage:  0.25252525252525254 Length:  99
# Scenario:  shipping_issue Total:  8 Percentage:  0.07547169811320754 Length:  106
# Scenario:  order_issue Total:  3 Percentage:  0.02857142857142857 Length:  105
# Scenario:  manage_account Total:  16 Percentage:  0.23529411764705882 Length:  68
# Scenario:  product_defect Total:  15 Percentage:  0.14285714285714285 Length:  105

# %% [markdown]
# ### Compute the Intersections between Train Set and Test Set

# %%
import json

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

guideline_path = "raw/guidelines.json"
with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))
guideline_action_seq = {}
for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    guideline_action_seq[scenario_name] = {}

    subflows = guidelines[scenario]['subflows']
    subflows_names = list(subflows.keys())
    for subflows_name in subflows_names:
        subflow = subflows[subflows_name]
        actions = subflow['actions']

        action_only = []
        for action in actions:
            action_only.append(action['button'])
        
        guideline_action_seq[scenario_name][subflows_name] = action_only

# print(json.dumps(guideline_action_seq, indent=2))
guideline_action_seq_scenario = {}
for scenario in guideline_action_seq.keys():
    for subflow in guideline_action_seq[scenario].keys():
        if scenario not in guideline_action_seq_scenario:
            guideline_action_seq_scenario[scenario] = []
        tmp = guideline_action_seq[scenario][subflow]
        for i in range(len(tmp)):
            tmp[i] = tmp[i].strip()
            tmp[i] = tmp[i].lower()
            tmp[i] = tmp[i].replace(" ", "-")
        guideline_action_seq_scenario[scenario].append(tmp)

# print(json.dumps(guideline_action_seq_scenario, indent=2))

data_actions = list(read_json_lines('processed/train_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

train_action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in train_action_seq_scenario:
            train_action_seq_scenario[scenario] = []

        train_action_seq_scenario[scenario].append(action_seq[convo_id][scenario])

data_actions = list(read_json_lines('processed/test_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

test_action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in test_action_seq_scenario:
            test_action_seq_scenario[scenario] = []

        test_action_seq_scenario[scenario].append(action_seq[convo_id][scenario])

# print(json.dumps(action_seq_scenario, indent=2))

# compute how many action flows are same in train set and test set
for scenario in train_action_seq_scenario.keys():
    train_actions = train_action_seq_scenario[scenario]
    test_actions = test_action_seq_scenario[scenario]
    guideline_actions = guideline_action_seq_scenario[scenario]
    
    total = 0
    for action_sequence in test_actions:
        if action_sequence in train_actions and action_sequence in guideline_actions:
            total += 1
    print("Scenario: ", scenario, "Total: ", total, "Percentage: ", total / len(test_actions), "Length: ", len(test_actions))
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# Scenario:  product_defect Total:  15 Percentage:  0.14285714285714285 Length:  105
# Scenario:  shipping_issue Total:  8 Percentage:  0.07547169811320754 Length:  106
# Scenario:  single_item_query Total:  0 Percentage:  0.0 Length:  106
# Scenario:  manage_account Total:  16 Percentage:  0.23529411764705882 Length:  68
# Scenario:  subscription_inquiry Total:  0 Percentage:  0.0 Length:  94
# Scenario:  troubleshoot_site Total:  0 Percentage:  0.0 Length:  103
# Scenario:  storewide_query Total:  0 Percentage:  0.0 Length:  107
# Scenario:  purchase_dispute Total:  0 Percentage:  0.0 Length:  111
# Scenario:  account_access Total:  25 Percentage:  0.25252525252525254 Length:  99
# Scenario:  order_issue Total:  3 Percentage:  0.02857142857142857 Length:  105

# %% [markdown]
# ### Compute matching rate of the action transitions between train and test sets

# %%
import json

# read lines from a json file, each line is a json object
def read_json_lines(file):
    with open(file, 'r') as f:
        for line in f:
            yield json.loads(line)

guideline_path = "/research/d5/gds/xywen22/project/llm_framework/guidedTOD/abcd/data/raw/guidelines.json"
with open(guideline_path, "r") as f:
    guidelines = json.load(f)

scenarios = guidelines.keys()
print("Scenarios: ", list(scenarios))
guideline_action_seq = {}
for scenario in scenarios:
    scenario_name = scenario.lower()
    scenario_name = scenario_name.replace("-", "_")
    scenario_name = scenario_name.replace(" ", "_")
    guideline_action_seq[scenario_name] = {}

    subflows = guidelines[scenario]['subflows']
    subflows_names = list(subflows.keys())
    for subflows_name in subflows_names:
        subflow = subflows[subflows_name]
        actions = subflow['actions']

        action_only = []
        for action in actions:
            action_only.append(action['button'])
        
        guideline_action_seq[scenario_name][subflows_name] = action_only

# print(json.dumps(guideline_action_seq, indent=2))
guideline_action_seq_scenario = {}
for scenario in guideline_action_seq.keys():
    for subflow in guideline_action_seq[scenario].keys():
        if scenario not in guideline_action_seq_scenario:
            guideline_action_seq_scenario[scenario] = []
        action_seq = guideline_action_seq[scenario][subflow]
        for i in range(len(action_seq)):
            action_seq[i] = action_seq[i].strip()
            action_seq[i] = action_seq[i].lower()
            action_seq[i] = action_seq[i].replace(" ", "-")
        
        # guideline_action_seq_scenario[scenario].append(tmp)
        for i in range(len(action_seq) - 1):
            if action_seq[i] not in guideline_action_seq_scenario[scenario]:
                guideline_action_seq_scenario[scenario].append([action_seq[i], action_seq[i+1]])

# print(json.dumps(guideline_action_seq_scenario, indent=2))

data_actions = list(read_json_lines('/research/d5/gds/xywen22/project/llm_framework/guidedTOD/abcd/data/processed/train_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

train_action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in train_action_seq_scenario:
            train_action_seq_scenario[scenario] = []

        # train_action_seq_scenario[scenario].append(action_seq[convo_id][scenario])
        for i in range(len(action_seq[convo_id][scenario]) - 1):
            if action_seq[convo_id][scenario][i] not in train_action_seq_scenario[scenario]:
                train_action_seq_scenario[scenario].append([action_seq[convo_id][scenario][i], action_seq[convo_id][scenario][i+1]])

data_actions = list(read_json_lines('/research/d5/gds/xywen22/project/llm_framework/guidedTOD/abcd/data/processed/test_AST_abcd_woaction_flow_all.json'))

action_seq = {}
for data_action in data_actions:
    convo_id = data_action['convo_id']
    action_scenario = data_action['flow']

    if convo_id not in action_seq:
        action_seq[convo_id] = {}
    if action_scenario not in action_seq[convo_id]:
        action_seq[convo_id][action_scenario] = []

    action_seq[convo_id][action_scenario].append(data_action['target'].split(':')[1].strip().split(' ')[0])

# print(json.dumps(action_seq, indent=2))

test_action_seq_scenario = {}
for convo_id in action_seq.keys():
    for scenario in action_seq[convo_id].keys():
        if scenario not in test_action_seq_scenario:
            test_action_seq_scenario[scenario] = []

        # test_action_seq_scenario[scenario].append(action_seq[convo_id][scenario])
        for i in range(len(action_seq[convo_id][scenario]) - 1):
            if action_seq[convo_id][scenario][i] not in test_action_seq_scenario[scenario]:
                test_action_seq_scenario[scenario].append([action_seq[convo_id][scenario][i], action_seq[convo_id][scenario][i+1]])

# print(json.dumps(action_seq_scenario, indent=2))

# compute how many action flows are same in train set and test set
for scenario in train_action_seq_scenario.keys():
    train_actions = train_action_seq_scenario[scenario]
    test_actions = test_action_seq_scenario[scenario]
    guideline_actions = guideline_action_seq_scenario[scenario]
    
    total = 0
    for action_sequence in test_actions:
        if action_sequence in train_actions or action_sequence in guideline_actions:
            total += 1
        # if action_sequence in guideline_actions:
            if action_sequence in guideline_actions:
                print(action_sequence)
    print("Scenario: ", scenario, "Total: ", total, "Percentage: ", total / len(test_actions), "Length: ", len(test_actions))
# Out:
# Scenarios:  ['Product Defect', 'Order Issue', 'Account Access', 'Troubleshoot Site', 'Manage Account', 'Purchase Dispute', 'Shipping Issue', 'Subscription Inquiry', 'Single-Item Query', 'Storewide Query']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['record-reason', 'enter-details']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'enter-details']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# ['enter-details', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['record-reason', 'offer-refund']
# ['pull-up-account', 'validate-purchase']
# ['enter-details', 'update-order']
# Scenario:  product_defect Total:  337 Percentage:  0.9853801169590644 Length:  342
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['validate-purchase', 'update-order']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['update-order', 'make-purchase']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'shipping-status']
# ['shipping-status', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'validate-purchase']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'update-order']
# ['update-order', 'make-purchase']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# Scenario:  shipping_issue Total:  341 Percentage:  0.9742857142857143 Length:  350
# Scenario:  single_item_query Total:  204 Percentage:  0.8947368421052632 Length:  228
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['update-account', 'offer-refund']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['update-account', 'offer-refund']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['ask-the-oracle', 'send-link']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['update-account', 'offer-refund']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['ask-the-oracle', 'send-link']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'ask-the-oracle']
# ['ask-the-oracle', 'send-link']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['verify-identity', 'update-account']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['ask-the-oracle', 'send-link']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# ['pull-up-account', 'ask-the-oracle']
# ['ask-the-oracle', 'send-link']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'ask-the-oracle']
# Scenario:  manage_account Total:  192 Percentage:  0.9948186528497409 Length:  193
# ['pull-up-account', 'verify-identity']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['ask-the-oracle', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['ask-the-oracle', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['ask-the-oracle', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['ask-the-oracle', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['subscription-status', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'subscription-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# Scenario:  subscription_inquiry Total:  327 Percentage:  0.9879154078549849 Length:  331
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['try-again', 'make-purchase']
# ['enter-details', 'make-purchase']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['enter-details', 'make-purchase']
# ['enter-details', 'make-purchase']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['try-again', 'instructions']
# ['enter-details', 'make-purchase']
# Scenario:  troubleshoot_site Total:  171 Percentage:  0.9715909090909091 Length:  176
# Scenario:  storewide_query Total:  231 Percentage:  0.9746835443037974 Length:  237
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['validate-purchase', 'ask-the-oracle']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# ['pull-up-account', 'validate-purchase']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['pull-up-account', 'record-reason']
# ['record-reason', 'verify-identity']
# Scenario:  purchase_dispute Total:  272 Percentage:  0.9679715302491103 Length:  281
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# ['pull-up-account', 'enter-details']
# ['pull-up-account', 'enter-details']
# ['enter-details', 'send-link']
# Scenario:  account_access Total:  185 Percentage:  1.0 Length:  185
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['shipping-status', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['shipping-status', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['ask-the-oracle', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['shipping-status', 'offer-refund']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['shipping-status', 'update-order']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'ask-the-oracle']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# ['pull-up-account', 'verify-identity']
# ['pull-up-account', 'verify-identity']
# ['verify-identity', 'shipping-status']
# Scenario:  order_issue Total:  277 Percentage:  0.9857651245551602 Length:  281
